# %%
import pandas as pd
import json

# %%
df = pd.read_csv('Figure_4__Daily_time_use_among_employed_adults_was_broadly_similar,_with_women_doing_more_unpaid_household_work_and_care,_while_there_was_variation_among_economically_inactive_adults.csv')
df
# Out:
#                     Unnamed: 0  Other activities  Education and study  \
# 0            Men in employment               1.3                  0.6
# 1          Women in employment               1.2                  0.4
# 2    Men economically inactive               1.1                  5.1
# 3  Women economically inactive               1.0                  2.3
#
#    Entertainment and leisure  Watching TV  Unpaid care  Unpaid household work  \
# 0                        8.8          8.3          1.8                    8.4
# 1                        8.7          7.6          2.7                   10.9
# 2                       13.7         10.5          1.2                   12.4
# 3                       11.3          9.1          4.2                   14.2
#
#    Travel  Paid work  Personal care  Sleep and rest
# 0     4.7       20.9            8.5            36.6
# 1     4.6       17.9            9.3            36.8
# 2     3.4        4.1            9.1            39.4
# ...

# %%
# Long format
long_df = df.melt(id_vars=[df.columns[0]], var_name="Category", value_name="Value")
long_df
# Out:
#                      Unnamed: 0                   Category  Value
# 0             Men in employment           Other activities    1.3
# 1           Women in employment           Other activities    1.2
# 2     Men economically inactive           Other activities    1.1
# 3   Women economically inactive           Other activities    1.0
# 4             Men in employment        Education and study    0.6
# 5           Women in employment        Education and study    0.4
# 6     Men economically inactive        Education and study    5.1
# 7   Women economically inactive        Education and study    2.3
# 8             Men in employment  Entertainment and leisure    8.8
# 9           Women in employment  Entertainment and leisure    8.7
# 10    Men economically inactive  Entertainment and leisure   13.7
# 11  Women economically inactive  Entertainment and leisure   11.3
# 12            Men in employment                Watching TV    8.3
# ...

# %%
long_df.to_csv('/content/long_format_data.csv', index=False)
